# %%
import os 
from dotenv import load_dotenv, find_dotenv 
_ = load_dotenv(find_dotenv())
groq_api_key = os.environ["GROQ_API_KEY"]

# %% [markdown]
# Chat Model

# %%
from langchain_groq import ChatGroq

llamachatmodel = ChatGroq(model='llama-3.1-8b-instant')

# %%
messages = [
    ("system","you are the math expert"),
    ("human","tell me example of linear algebra"),
]

# %%
llamaresponse = llamachatmodel.invoke(messages)
print(llamaresponse.content)
# Out:
# Linear Algebra is a branch of mathematics that deals with the study of linear equations, vector spaces, linear transformations, and matrices. Here are some examples of linear algebra:
#
# **Example 1: Finding the Equation of a Line**
#
# Suppose we have two points on a line: (x1, y1) = (2, 3) and (x2, y2) = (4, 5). We can use linear algebra to find the equation of the line. The slope of the line (m) is given by:
#
# m = (y2 - y1) / (x2 - x1)
# = (5 - 3) / (4 - 2)
# = 2 / 2
# = 1
#
# Now, we can use the point-slope form of a line (y - y1 = m(x - x1)) to find the equation of the line:
#
# y - 3 = 1(x - 2)
# y - 3 = x - 2
# y = x + 1
#
# **Example 2: Finding the Inverse of a Matrix**
#
# Suppose we have a matrix:
#
# A = | 1  2  |
#     | 3  4  |
#
# To find the inverse of A (A^(-1)), we can use the formula:
#
# A^(-1) = (1 / det(A)) \* adj(A)
#
# where det(A) is the determinant of A, and adj(A) is the adjoint matrix of A.
#
# The determinant of A is:
#
# det(A) = (1 \* 4) - (2 \* 3)
# = 4 - 6
# = -2
#
# The adjoint matrix of A is:
#
# adj(A) = | 4  -2 |
#        | -3   1  |
#
# Now, we can calculate the inverse of A:
#
# A^(-1) = (1 / (-2)) \* adj(A)
# = (-1/2) \* | 4  -2 |
#            | -3   1  |
# = | -2   1 |
#   | 3/2 -1/2 |
#
# **Example 3: Finding the Eigenvalues of a Matrix**
#
# Suppose we have a matrix:
#
# A = | 2  1 |
#     | 1  2  |
#
# To find the eigenvalues of A, we can solve the characteristic equation:
#
# | A - λI | = 0
#
# where λ is the eigenvalue, and I is the identity matrix.
#
# The characteristic equation is:
#
# | 2 - λ  1   |
# | 1     2 - λ |
#
# Expanding the determinant, we get:
#
# (2 - λ)^2 - 1 = 0
# λ^2 - 4λ + 3 = 0
#
# Solving for λ, we get:
#
# λ = (4 ± √(16 - 12)) / 2
# = (4 ± √4) / 2
# = (4 ± 2) / 2
# = 3 or 1
#
# Therefore, the eigenvalues of A are λ = 3 and λ = 1.
#
# These are just a few examples of linear algebra. There are many more concepts and techniques in linear algebra, including vector spaces, linear transformations, and orthogonal projections.
